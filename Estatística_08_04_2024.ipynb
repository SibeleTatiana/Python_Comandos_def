# %% [markdown]
# <a href="https://colab.research.google.com/github/SibeleTatiana/WebAggregat/blob/main/Estat%C3%ADstica_08_04_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Distribuições discretas

# %%
1)Distribuições Uniforme
Todos os valores possuem a mesma probalidade.
Exemplo: "Qual a chance de sair 2 em um dado?" --> 1/6
"Qual a chance de sair 6?" -->1/6
# Out:
#   File "<ipython-input-6-a09e849547fa>", line 1
#     1)Distribuições Uniforme
#      ^
# SyntaxError: unmatched ')'

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats  import binom, poisson

# %% [markdown]
# # Distribuição Uniforme

# %%
#Definindo o número de faces do dado
num_faces = 6

#Calculando a probabilidade de cada face
probabilidade = 1 / num_faces

print("A probalidade de cada face do dado de 6 faces é de ", probalidade)
# Out:
# A probalidade de cada face do dado de 6 faces é de  0.16666666666666666

# %%
#Criando os valores de x (faces do dado) e y (probalidades)
faces = np.arange(1, num_faces+1)
probabilidades = np.full(6, probabilidade)

#Plotando o gráfico
plt.figure(figsize=(8,6))
plt.bar(faces,probabilidades,color='skyblue', alpha=0.7)
plt.title('Distribuição Uniforme de um Dado de 6 Faces')
plt.xlabel ('Face do Dado')
plt.ylabel ('Probabilidade')
plt.xticks(faces)
plt.grid (axis= 'y', linestyle ='--', alpha = 0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#Definindo o intervalo de tempo entre os ônibus (em minutos)
intervalo_ônibus = 20

#Número total de intervalos de 20 minutos em um período de 1 hora (60 minutos)
n_intervalos = 60// intervalo_ônibus

#Criando a probabilidade de cada intervalo de tempo
probabilidade = 1/n_intervalos

#Criando os valores de x (intervalos de tempo) e y (probabilidades)
intervalos_tempo = np.arange (intervalo_ônibus, 61, intervalo_ônibus)
probabilidades = np.full(n_intervalos, probabilidade)

#Plotando o gráfico
plt.figure(figsize=(10,6))
plt.bar(intervalos_tempo, probabilidades, width=5, color='skyblue', alpha=0.7)
plt.title('Distribuição Uniforme : Horário de chegada dos Ônibus')
plt.xlabel ('Tempo (minutos)')
plt.ylabel ('Probabilidade')
plt.xticks(faces)
plt.grid (axis= 'y', linestyle ='--', alpha = 0.7)
plt.show()

# %% [markdown]
# # **2)Distribuição de Bernoulli (Revisão)**

# %% [markdown]
# # **Probabilidade de um único evento ocorrer e um única tentativa, ou seja, a probabilidade de sucesso em um único ensaio.
#
# --> P(x)= p(1-p)

# %% [markdown]
# # New Section

# %%
import math


#Definindo a média mensal de acidentes (lambda)
lambd = 20

#número de acidentes que queremos calcular a probabilidade
k = 7
#número a probabilidade usando a fórmula da distribuição de Poisson
probabilidade = (math.exp(-lambd) * (lambd ** k)) / math.factorial(k)

print(f"A probabilidade de ocorrerem 7 acidentes \ é de aproximadamente {probabilidade:.4f}")
# Out:
# A probabilidade de ocorrerem 7 acidentes \ é de aproximadamente 0.0005
